# %%
import utilis.funs as funs
from config.boundaries import boundaries  # the ranges for each function

# %%
import pandas as pd
import os
import glob

# %%
i=1
data = pd.read_csv("../../data/"+str(i)+".csv")

# %%
set_id = 1
noise_level=0
random_seed = 1
method = "MI"
folder = "data_" + str(set_id)  + "_noise_" + str(noise_level) + "_seed_" + str(random_seed)
point_folder = os.path.join("../../out_data", folder, method,"train*")
point_path = glob.glob(point_folder)[0]
points = pd.read_csv(point_path)

# %%
points
# Out:
#     Unnamed: 0         x         y         z
# 0        X1301  0.000000  0.768116  1.000000
# 1        X1824  0.753623  0.043478  0.440285
# 2        X2806  0.927536  0.101449  0.197159
# 3        X4448  0.753623  0.710145  0.247379
# 4         X988  0.869565  0.927536  0.248587
# 5        X4398  1.000000  0.289855  0.812153
# 6        X4624  0.666667  0.666667  0.199209
# 7        X3234  0.057971  0.594203  0.974239
# 8        X3078  0.507246  1.000000  0.142509
# 9         X303  0.246377  0.550725  0.866438
# 10       X1008  0.028986  0.130435  0.937088
# 11        X864  0.231884  0.507246  0.997430
# 12       X3359  0.797101  0.260870  0.141597
# 13       X1878  0.768116  0.594203  0.185261
# 14       X3762  0.884058  1.000000  0.185764
# 15       X2432  0.811594  0.710145  0.188179
# 16       X3505  0.057971  0.028986  0.722776
# 17       X4844  0.478261  0.927536  0.249459
# 18       X1856  0.927536  0.159420  0.147096
# 19       X3795  0.768116  0.695652  0.209756
# 20       X4562  0.202899  0.637681  0.455894
# 21       X1036  0.072464  0.405797  0.960020
# 22       X3179  0.057971  0.637681  0.947223
# 23        X613  0.913043  0.855072  0.179789
# 24       X1303  0.420290  0.550725  0.639683
# 25       X1883  0.057971  0.260870  0.863716
# 26         X66  0.811594  0.057971  0.047707
# 27       X1864  0.927536  0.942029  0.059008
# 28       X4238  0.391304  0.855072  0.175165
# 29       X1658  0.376812  0.971014  0.096843
# ..         ...       ...       ...       ...
# 143      X3193  0.666667  0.449275  0.243211
# 144      X1953  0.652174  0.420290  0.185680
# 145     X976.1  0.840580  0.188406  0.876752
# 146      X4762  0.594203  0.956522  0.595926
# 147    X4762.1  0.594203  0.956522  0.595926
# 148      X3424  0.159420  0.608696  0.759638
# 149       X499  0.608696  0.956522  0.729672
# 150     X499.1  0.608696  0.956522  0.729672
# 151       X586  0.376812  0.637681  0.169873
# 152       X710  0.333333  0.130435  0.168543
# 153     X710.1  0.333333  0.130435  0.168543
# 154      X1182  0.057971  0.115942  0.753416
# 155       X829  0.347826  0.724638  0.179770
# 156     X829.1  0.347826  0.724638  0.179770
# 157       X690  0.304348  0.043478  0.157073
# 158      X4741  0.130435  0.840580  0.156546
# 159    X4741.1  0.130435  0.840580  0.156546
# 160      X1153  0.739130  0.202899  0.646700
# 161      X1562  0.826087  0.159420  0.660328
# 162    X1562.1  0.826087  0.159420  0.660328
# 163       X284  0.695652  0.275362  0.230502
# 164      X3894  0.666667  0.985507  0.996753
# 165    X3894.1  0.666667  0.985507  0.996753
# 166      X4213  0.115942  0.666667  0.720426
# 167      X2843  0.521739  0.666667  0.014954
# 168    X2843.1  0.521739  0.666667  0.014954
# 169      X3744  0.086957  0.072464  0.459892
# 170      X1695  0.333333  0.695652  0.249840
# 171    X1695.1  0.333333  0.695652  0.249840
# 172      X2188  0.869565  0.449275  0.045176
#
# [173 rows x 4 columns]

# %%
from mpl_toolkits.mplot3d import Axes3D
import matplotlib.pyplot as plt
import numpy as np
#%matplotlib inline



fig = plt.figure()
ax = fig.gca(projection='3d')

ax.plot_trisurf(data.iloc[:,0], data.iloc[:,1], data.iloc[:,2], linewidth=0.2, antialiased=True)
ax.scatter3D(points.iloc[:,1],points.iloc[:,2],points.iloc[:,3],c='b')
plt.show()

# %%
plt.scatter(points.iloc[:50,1],points.iloc[:50,2])
plt.show()

# %%
import sys
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.animation import FuncAnimation
import pylab as pl

fig, ax = plt.subplots()
fig.set_tight_layout(True)

# Query the figure's on-screen size and DPI. Note that when saving the figure to
# a file, we need to provide a DPI for that separately.
print('fig size: {0} DPI, size in inches {1}'.format(
    fig.get_dpi(), fig.get_size_inches()))

# Plot a scatter that persists (isn't redrawn) and the initial line.

ax.scatter(points.iloc[:50,1],points.iloc[:50,2])

def update(i):
    ax.scatter(points.iloc[50+i-3:50+i,1],points.iloc[50+i-3:50+i,2],marker= "*")
    pl.text(points.iloc[50+i-3:50+i,1],points.iloc[50+i-3:50+i,2], str(i), color="red", fontsize=12)
    return ax


anim = FuncAnimation(fig, update, frames=np.arange(3, 123,3), interval=10000)
anim.save('../../out_fig/line.gif', dpi=150, writer='imagemagick')
# Out:
# fig size: 72.0 DPI, size in inches [ 6.  4.]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-43-208c8ccfdfbe> in <module>()
#      24
#      25 anim = FuncAnimation(fig, update, frames=np.arange(3, 123,3), interval=10000)
# ---> 26 anim.save('../../out_fig/line.gif', dpi=150, writer='imagemagick')
#
# /home/wxk/anaconda2/envs/py3/lib/python3.6/site-packages/matplotlib/animation.py in save(self, filename, writer, fps, dpi, codec, bitrate, extra_args, metadata, extra_anim, savefig_kwargs)
#    1060                     for anim, d in zip(all_anim, data):
#    1061                         # TODO: See if turning off blit is really necessary
# -> 1062                         anim._draw_next_frame(d, blit=False)
#    1063                     writer.grab_frame(**savefig_kwargs)
#    1064
#
# /home/wxk/anaconda2/envs/py3/lib/python3.6/site-packages/matplotlib/animation.py in _draw_next_frame(self, framedata, blit)
#    1098         self._pre_draw(framedata, blit)
#    1099         self._draw_frame(framedata)
# -> 1100         self._post_draw(framedata, blit)
#    1101
#    1102     def _init_draw(self):
#
# /home/wxk/anaconda2/envs/py3/lib/python3.6/site-packages/matplotlib/animation.py in _post_draw(self, framedata, blit)
#    1123             self._blit_draw(self._drawn_artists, self._blit_cache)
#    1124         else:
# -> 1125             self._fig.canvas.draw_idle()
#    1126
#    1127     # The rest of the code in this class is to facilitate easy blitting
#
# /home/wxk/anaconda2/envs/py3/lib/python3.6/site-packages/matplotlib/backend_bases.py in draw_idle(self, *args, **kwargs)
#    2038         if not self._is_idle_drawing:
#    2039             with self._idle_draw_cntx():
# -> 2040                 self.draw(*args, **kwargs)
#    2041
#    2042     def draw_cursor(self, event):
#
# /home/wxk/anaconda2/envs/py3/lib/python3.6/site-packages/matplotlib/backends/backend_agg.py in draw(self)
#     462
#     463         try:
# --> 464             self.figure.draw(self.renderer)
#     465         finally:
#     466             RendererAgg.lock.release()
#
# /home/wxk/anaconda2/envs/py3/lib/python3.6/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      61     def draw_wrapper(artist, renderer, *args, **kwargs):
#      62         before(artist, renderer)
# ---> 63         draw(artist, renderer, *args, **kwargs)
#      64         after(artist, renderer)
#      65
#
# /home/wxk/anaconda2/envs/py3/lib/python3.6/site-packages/matplotlib/figure.py in draw(self, renderer)
#    1142
#    1143             mimage._draw_list_compositing_images(
# -> 1144                 renderer, self, dsu, self.suppressComposite)
#    1145
#    1146             renderer.close_group('figure')
#
# /home/wxk/anaconda2/envs/py3/lib/python3.6/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, dsu, suppress_composite)
#     137     if not_composite or not has_images:
#     138         for zorder, a in dsu:
# --> 139             a.draw(renderer)
#     140     else:
#     141         # Composite any adjacent images together
#
# /home/wxk/anaconda2/envs/py3/lib/python3.6/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      61     def draw_wrapper(artist, renderer, *args, **kwargs):
#      62         before(artist, renderer)
# ---> 63         draw(artist, renderer, *args, **kwargs)
#      64         after(artist, renderer)
#      65
#
# /home/wxk/anaconda2/envs/py3/lib/python3.6/site-packages/matplotlib/axes/_base.py in draw(self, renderer, inframe)
#    2424             renderer.stop_rasterizing()
#    2425
# -> 2426         mimage._draw_list_compositing_images(renderer, self, dsu)
#    2427
#    2428         renderer.close_group('axes')
#
# /home/wxk/anaconda2/envs/py3/lib/python3.6/site-packages/matplotlib/image.py in _draw_list_compositing_images(renderer, parent, dsu, suppress_composite)
#     137     if not_composite or not has_images:
#     138         for zorder, a in dsu:
# --> 139             a.draw(renderer)
#     140     else:
#     141         # Composite any adjacent images together
#
# /home/wxk/anaconda2/envs/py3/lib/python3.6/site-packages/matplotlib/artist.py in draw_wrapper(artist, renderer, *args, **kwargs)
#      61     def draw_wrapper(artist, renderer, *args, **kwargs):
#      62         before(artist, renderer)
# ---> 63         draw(artist, renderer, *args, **kwargs)
#      64         after(artist, renderer)
#      65
#
# /home/wxk/anaconda2/envs/py3/lib/python3.6/site-packages/matplotlib/text.py in draw(self, renderer)
#     752
#     753         with _wrap_text(self) as textobj:
# --> 754             bbox, info, descent = textobj._get_layout(renderer)
#     755             trans = textobj.get_transform()
#     756
#
# /home/wxk/anaconda2/envs/py3/lib/python3.6/site-packages/matplotlib/text.py in _get_layout(self, renderer)
#     333         of a rotated text when necessary.
#     334         """
# --> 335         key = self.get_prop_tup(renderer=renderer)
#     336         if key in self._cached:
#     337             return self._cached[key]
#
# /home/wxk/anaconda2/envs/py3/lib/python3.6/site-packages/matplotlib/text.py in get_prop_tup(self, renderer)
#     907         need to know if the text has changed.
#     908         """
# --> 909         x, y = self.get_unitless_position()
#     910         return (x, y, self.get_text(), self._color,
#     911                 self._verticalalignment, self._horizontalalignment,
#
# /home/wxk/anaconda2/envs/py3/lib/python3.6/site-packages/matplotlib/text.py in get_unitless_position(self)
#     889         # This will get the position with all unit information stripped away.
#     890         # This is here for convienience since it is done in several locations.
# --> 891         x = float(self.convert_xunits(self._x))
#     892         y = float(self.convert_yunits(self._y))
#     893         return x, y
#
# /home/wxk/anaconda2/envs/py3/lib/python3.6/site-packages/pandas/core/series.py in wrapper(self)
#      95             return converter(self.iloc[0])
#      96         raise TypeError("cannot convert the series to "
# ---> 97                         "{0}".format(str(converter)))
#      98
#      99     return wrapper
#
# TypeError: cannot convert the series to <class 'float'>

# %%
np.arange(3, 123,3)
# Out:
# array([  3,   6,   9,  12,  15,  18,  21,  24,  27,  30,  33,  36,  39,
#         42,  45,  48,  51,  54,  57,  60,  63,  66,  69,  72,  75,  78,
#         81,  84,  87,  90,  93,  96,  99, 102, 105, 108, 111, 114, 117, 120])
